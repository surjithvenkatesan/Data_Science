# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.imdb.com/chart/top/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

movies = soup.find_all("li", class_="ipc-metadata-list-summary-item")

data = []

for movie in movies:
    title = movie.find("h3").text.strip()

    year = movie.find("span", class_="sc-4b408797-8").text.strip()

    rating = movie.find("span", class_="ipc-rating-star--rating").text.strip()

    data.append([title, year, rating])

df = pd.DataFrame(data, columns=["Movie", "Year", "Rating"])

df.to_csv("dataset.csv", index=False)


print("CSV created successfully!")
print(df)
# Out:
# 0
# CSV created successfully!
# Empty DataFrame
# Columns: [Movie, Year, Rating]
# Index: []
