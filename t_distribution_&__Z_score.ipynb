# %%
import numpy as np
import pandas as pd
import random
import scipy.stats as st
sample=[12,13,16,17,22,26,27,28,29]
st.t.interval(confidence=0.95,df=len(sample)-1,loc=np.mean(sample),scale=st.sem(sample))
# Out:
# (np.float64(15.94836712941827), np.float64(26.273855092803952))

# %%
import pandas as pd
import scipy.stats as st
import numpy as np
c=pd.read_csv("/content/Delivery_Logistics.csv")
d=c["distance_km"]

f=d.sample(n=200)

np.mean(f)

rest=st.t.interval(confidence=0.95, df=len(f)-1,loc=np.mean(f),scale=st.sem(f))
#resz=st.z.interval(confidence=0.95, df=len(f)-1,loc=np.mean(f),scale=st.sem(f))
rest
#resz
# Out:
# (np.float64(142.6363417026795), np.float64(167.9696582973205))

# %%
from scipy.stats import zscore
d=pd.read_csv("/content/powerconsumption.csv")
a=d['PowerConsumption_Zone1']
ans=zscore(a)
print(f"Z - Score result is {ans}" )
# Out:
# Z - Score result is [ 0.23991683 -0.35485435 -0.45114252 ... -0.38624194 -0.47497346
#  -0.56029223]

# %%
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# ...

# %%
h=pd.read_csv('/content/banking_dataset.csv')
s=h['Monthly_Salary']
out=zscore(s)
print(f"Z - Score result is {out}" )
# Out:
# Z - Score result is [-1.14522267 -0.99453548 -0.5424739  -0.3917867  -0.24109951 -0.09041232
#   0.06027488  0.21096207  0.51233646  2.62195717]
